# %%
#Importação de bibliotecas para tratamento dos dados
#Nesse case vamos utilizar a biblioteca do Yahoo! Finance para obter os preços de ações
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import yfinance as yf
import seaborn as sns

# %%
tickers = ['ARZZ3.SA','B3SA3.SA','CRFB3.SA','KLBN11.SA','AMER3.SA',
          'MULT3.SA','PETR4.SA','RENT3.SA','SULA11.SA','VALE3.SA']
dfret = yf.download(ticker, start = "2019-08-30", end = "2021-08-27")
