# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# ## 1) Cálculo do VaR Histórico

# %%
# colocar o nome da ação, junto com ".SA: 
ticker = ['ARZZ3.SA']

# %%
# insere o período histórico da ação
data = yf.download(ticker, start='2022-01-01', end='2023-01-03')
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-01-03  78.000000  78.000000  72.000000  72.230003  68.455521  1080000
# 2022-01-04  72.860001  72.860001  69.849998  70.099998  66.436813   771200
# 2022-01-05  69.809998  70.040001  65.910004  66.730003  63.242916  1645600
# 2022-01-06  66.620003  68.339996  64.589996  67.949997  64.399162  1938400
# 2022-01-07  68.080002  68.849998  66.529999  67.410004  63.887390   487500
# ...               ...        ...        ...        ...        ...      ...
# 2022-12-26  80.760002  80.760002  77.470001  78.559998  76.290283   525600
# 2022-12-27  78.820000  78.900002  75.930000  76.570000  74.357788  1218700
# 2022-12-28  76.919998  79.300003  76.629997  78.680000  76.406822   970700
# 2022-12-29  79.980003  80.180000  76.949997  78.250000  75.989250  1199700
# 2023-01-02  77.889999  77.889999  72.510002  74.120003  71.978569  1008600
#
# [251 rows x 6 columns]

# %%
# calcula os retornos (que nada mais são do que a variação percentual do preço da ação ao longo do tempo)
returns = data['Adj Close'].pct_change().dropna()
returns
# Out:
# Date
# 2022-01-04   -0.029489
# 2022-01-05   -0.048074
# 2022-01-06    0.018283
# 2022-01-07   -0.007947
# 2022-01-10   -0.039015
#                 ...
# 2022-12-26   -0.028324
# 2022-12-27   -0.025331
# 2022-12-28    0.027556
# 2022-12-29   -0.005465
# 2023-01-02   -0.052780
# Name: Adj Close, Length: 250, dtype: float64

# %%
# calcula o percentil 5% do VaR
alpha = 0.05
var = np.percentile(returns, alpha*100)
var
# Out:
# -0.03895768047603036

# %%
# plota o histograma dos retornos com a linha do percentil do VaR
plt.hist(returns, bins=50)
plt.axvline(x=var, color='r', linestyle='--', label='VaR')
plt.xlim(-0.1,0.1)
plt.legend()
plt.title(f"O VaR histórico de {ticker} é {var:.2%}.")
plt.show()

# %% [markdown]
# ## 2) Visualizando os Retornos e VaRs para mais ações de forma automática

# %%
# define as acoes
tickers = ['CIEL3.SA',
'CURY3.SA',
'DESK3.SA',
'EMBR3.SA',
'ORVR3.SA',
'PSSA3.SA',
'SMFT3.SA',
'SMTO3.SA',
'STBP3.SA']

# %%
# Define o tamanho da matriz de histogramas de retornos de ações
nrows = 3
ncols = 3

tickers = np.array(tickers).reshape(nrows,ncols)
tickers[0][0]
'''
#função para gerar os retornos e VaR de cada ação
def gera_var(i,j):
    
    data = yf.download(tickers[i][j], start='2022-01-01', end='2023-01-03');

    returns = data['Adj Close'].pct_change().dropna()

    alpha = 0.05
    var = np.percentile(returns, alpha*100)

    return returns , var'''
# Out:
# "\n#função para gerar os retornos e VaR de cada ação\ndef gera_var(i,j):\n    \n    data = yf.download(tickers[i][j], start='2022-01-01', end='2023-01-03');\n\n    returns = data['Adj Close'].pct_change().dropna()\n\n    alpha = 0.05\n    var = np.percentile(returns, alpha*100)\n\n    return returns , var"

# %%
# Cria a matriz de histogramas
fig, axs = plt.subplots(nrows, ncols, figsize=(20, 15))

for i in range(nrows):
    for j in range(ncols):
        
        returns , var = gera_var(i,j)
        
        axs[i,j].hist(returns, bins=50)
        axs[i,j].axvline(x=var, color='r', linestyle='--', label='VaR')
        axs[i,j].set_xlim(-0.1,0.1)
        axs[i,j].legend()
        axs[i,j].set_title(f"O VaR histórico de {tickers[i][j]} é {var:.2%}.")

#plt.show
returns.index
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# DatetimeIndex(['2022-01-04', '2022-01-05', '2022-01-06', '2022-01-07',
#                '2022-01-10', '2022-01-11', '2022-01-12', '2022-01-13',
#                '2022-01-14', '2022-01-17',
#                ...
#                '2022-12-19', '2022-12-20', '2022-12-21', '2022-12-22',
#                '2022-12-23', '2022-12-26', '2022-12-27', '2022-12-28',
#                '2022-12-29', '2023-01-02'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)
